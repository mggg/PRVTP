# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.optimize import fsolve
from functools import partial
from matplotlib.lines import Line2D 
from pathlib import Path

# %%
b_fpv_list = [round(x, 2) for x in np.arange(0.55, .99, 0.1)]
a_fpv_list = [round(x, 2) for x in np.arange(0.55, .99, 0.1)]
b_prop_list = [x/100 for x in range(5, 100, 10)]

generators=["slate-CS-C", "slate-CS-W", "slate-BT", "slate-PL"]
colors= {"slate-CS-C":'#1560BD',
        "slate-CS-W":'#FB607F',
         "slate-BT":'#8DB600',
         "slate-PL":'#FFBF00'}

pi_types_dirichlet=["UU", "UX", "XXsame", "XXdif"]


dirichlet_markers = {"UU":"o", 
"UX":"v", 
"XXsame":"^",
"XXdif":"s",}

# %% [markdown]
# # Dirichlet

# %%
N_TRIALS = 100
N_BALLOTS = 5000
N_SEATS = 5
N_CANDS_PER_BLOC = 5

uniform_dirichlet = 2.0
strong_dirichlet = .5

election_path_name = f'/cluster/tufts/mggg/cdonna01/PRVTP_feb_25_submission/run_elections/election_results/2_bloc/dirichlet'

# %%
b_fpv_list = [round(x, 2) for x in np.arange(0.55, .99, 0.1)]
a_fpv_list = [round(x, 2) for x in np.arange(0.55, .99, 0.1)]
b_prop_list = [x/100 for x in range(5, 100, 10)]


dirichlet_dfs = {}
failed = []
i=0
for b_prop in b_prop_list:
    for g in generators:
        for pi_type in pi_types_dirichlet:
            for fpv_b in b_fpv_list:
                for fpv_a in a_fpv_list:
                    try:
                        i+=1
                        sub_path_name = f"seats_{N_SEATS}/cperbloc_{N_CANDS_PER_BLOC}/trials_{N_TRIALS}/ballots_{N_BALLOTS}/fpv_b_{fpv_b}/fpv_a_{fpv_a}/b_prop_{b_prop}/{g}/pi_type_{pi_type}/dunif_{uniform_dirichlet}/dstrong_{strong_dirichlet}/"
                        file_name = f"seats_{N_SEATS}_cperbloc_{N_CANDS_PER_BLOC}_trials_{N_TRIALS}_ballots_{N_BALLOTS}_fpv_b_{fpv_b}_fpv_a_{fpv_a}_b_prop_{b_prop}_{g}_pi_type_{pi_type}_dunif_{uniform_dirichlet}_dstrong_{strong_dirichlet}"
                        df = pd.read_csv(f"{election_path_name}/{sub_path_name}/{file_name}.csv")
                        dirichlet_dfs[(fpv_b, fpv_a, b_prop,g, pi_type)] = df
                    except Exception as e:
                        print(e)
                        print((fpv_b, fpv_a, b_prop, g, pi_type),"\n")
                        failed.append((fpv_b, fpv_a, b_prop, g, pi_type))

# %%
for x in failed:
    print(f"'{x[0]} {x[1]} {x[2]} {x[3]} {x[4]}' \\")

# %%
b_fpv_list = [round(x, 2) for x in np.arange(0.55, .99, 0.1)]
a_fpv_list = [round(x, 2) for x in np.arange(0.55, .99, 0.1)]
b_prop_list = [x/100 for x in range(5, 100, 10)]


for election_type in ["stv", "borda"]:
    STAT = "Expected FPV"

    fig, ax = plt.subplots(figsize=(14,14))
    ax.step(
        np.linspace(0,1,N_SEATS+1),
        np.arange(0,1.1, 1/N_SEATS),
        linestyle = 'dashed',
        c='gray',
        where='pre'
    )
    ax.step(
        np.linspace(0,1,N_SEATS+1),
        np.arange(0,1.1, 1/N_SEATS),
        linestyle = 'dashed',
        c='gray',
        where='post'
    )
    ax.set_ylabel(f'Average Share of Elected B Candidates\n Over {N_TRIALS} Trials')
    ax.set_xlabel(f'Combined Support for B via {STAT}')

    data  = [-1]* len(generators)*len(b_prop_list)*len(pi_types_dirichlet)*len(b_fpv_list)*len(a_fpv_list)
    i=0
    for g in generators:
        for b_prop in b_prop_list:
            for pi_type in pi_types_dirichlet:
                for b_fpv in b_fpv_list:
                    for a_fpv in a_fpv_list:
                        df = dirichlet_dfs[(b_fpv, a_fpv, b_prop, g, pi_type)]
                        
                        # combined support
                        x = b_fpv*b_prop  + (1-a_fpv)*(1-b_prop)
                        
                        # average seats over trials
                        y = df[f"avg B cands elected {election_type}"].iloc[0]/N_SEATS 
                        ax.scatter(x, y,
                                    label=g,
                                    marker = dirichlet_markers[pi_type],
                                    edgecolor=colors[g], 
                                    facecolor='none'
                                )
                        data[i]=(x,y)
                        i+=1
                        
    avg_sc = sum(y-x for (x,y) in data)/len(data)
    avg_abs_sc = sum(abs(y-x) for (x,y) in data)/len(data)
    print(f"Average S-C {avg_sc:.2f}")
    print(f"Average |S-C| {avg_abs_sc:.2f}")


    legend_elements = [
        Line2D([0], [0], marker='.', color=colors[g], label=g, markersize=15)
        for g in generators
    ] + [Line2D([0], [0], marker=dirichlet_markers[pi_type], color="grey", label=pi_type, markersize=10)
        for pi_type in pi_types_dirichlet] 


    plt.ylim(-.1, 1.1)
    plt.legend(handles=legend_elements)
    if election_type == "stv":
        election_type = election_type.upper()
    else:
        election_type = election_type.capitalize()

    plt.suptitle(f"Combined support vs. {election_type} results\n2 bloc profile\n\
        {N_TRIALS} trials, {N_BALLOTS} ballots, {N_SEATS} seats, {N_CANDS_PER_BLOC} candidates per bloc\n\
            b_coh {b_fpv_list}\n a_coh {a_fpv_list}\n b_prop {b_prop_list}\
                \n Dirichlet\nAverage S-C {avg_sc:.2f}\nAverage |S-C| {avg_abs_sc:.2f}")
    plt.tight_layout()
    # plt.show()

    path_name = f"/cluster/tufts/mggg/cdonna01/PRVTP_feb_25_submission/deg_of_prop/figures/{N_SEATS}_seats/{STAT}_combined_support/all_models/{election_type}"
    file_name = f"{N_SEATS}_seats_combined_support_{election_type}.png"
    path = Path(path_name)

    plt.savefig(f"{path_name}/{file_name}", dpi=300)
# Out:
# Average S-C -0.02
# Average |S-C| 0.08
# Average S-C -0.01
# Average |S-C| 0.14

# %% [markdown]
# # Degree by Parameter

# %%
degrees = {"generator":[],
            "pi_type":[],
            "cohesion":[],
            "Average S-C stv":[],
            "Average S-C borda":[],
            "Average |S-C| stv": [],
            "Average |S-C| borda": [],
            }


STAT = "Expected FPV"


for g in generators:
    for pi_type in pi_types_dirichlet:
        for cohesion in ["full", "polarized"]:
            degrees["generator"].append(g)
            degrees["pi_type"].append(pi_type)
            degrees["cohesion"].append(cohesion)
            for election_type in ["stv", "borda"]:
                print("\n",election_type, g, pi_type, f"cohesion {cohesion}")

                if cohesion == "full":
                    b_coh_list = [round(x, 2) for x in np.arange(0.55, .99, 0.1)]
                    a_coh_list = [round(x, 2) for x in np.arange(0.55, .99, 0.1)]
                else:
                    b_coh_list = [round(x, 2) for x in np.arange(0.75, .99, 0.1)]
                    a_coh_list = [round(x, 2) for x in np.arange(0.75, .99, 0.1)]


                b_prop_list = [x/100 for x in range(5, 100, 10)]

                
                fig, ax = plt.subplots(figsize=(14,14))
                ax.step(
                    np.linspace(0,1,N_SEATS+1),
                    np.arange(0,1.1, 1/N_SEATS),
                    linestyle = 'dashed',
                    c='gray',
                    where='pre'
                )
                ax.step(
                    np.linspace(0,1,N_SEATS+1),
                    np.arange(0,1.1, 1/N_SEATS),
                    linestyle = 'dashed',
                    c='gray',
                    where='post'
                )
                ax.set_ylabel(f'Average Share of Elected B Candidates\n Over {N_TRIALS} Trials')
                ax.set_xlabel(f'Combined Support for B via {STAT}')
            
                data  = []
                for b_prop in b_prop_list:
                    for b_fpv in b_coh_list:
                        for a_fpv in a_coh_list:
                            df = dirichlet_dfs[(b_fpv, a_fpv, b_prop, g, pi_type)]
                            x = b_fpv*b_prop  + (1-a_fpv)*(1-b_prop)
                            
                            # average seats over trials
                            y = df[f"avg B cands elected {election_type}"].iloc[0]/N_SEATS 

                            data.append((x,y))
                            ax.scatter(x, y,
                                label=g,
                                marker = dirichlet_markers[pi_type],
                                edgecolor=colors[g], 
                                facecolor=colors[g]
                            )
                
            
                avg_sc = sum(y-x for (x,y) in data)/len(data)
                avg_abs_sc = sum(abs(y-x) for (x,y) in data)/len(data)
                
                degrees[f"Average S-C {election_type}"].append(avg_sc)
                degrees[f"Average |S-C| {election_type}"].append(avg_abs_sc)

                print(f"Average S-C {avg_sc:.2f}")
                print(f"Average |S-C| {avg_abs_sc:.2f}")
                
                legend_elements = [
                    Line2D([0], [0], marker='.', color=colors[g], label=g, markersize=15)
                    for g in [g]
                ] + [Line2D([0], [0], marker=dirichlet_markers[pi_type], color="grey", label=pi_type, markersize=10)
                    for pi_type in [pi_type]]

                plt.ylim(-.1, 1.1)
                plt.legend(handles=legend_elements)

                plt.suptitle((f"Combined support vs. {election_type.upper() if election_type == 'stv' else election_type.capitalize()} results\n2 bloc profile\n{N_TRIALS} trials, "
                        f"{N_BALLOTS} ballots, {N_SEATS} seats, {N_CANDS_PER_BLOC} candidates per bloc\n"
                        f"pi_B {b_coh_list}\n pi_A {a_coh_list}\n b_prop {b_prop_list}\n Dirichlet"
                            f"\nAverage S-C {avg_sc:.2f}\nAverage |S-C| {avg_abs_sc:.2f}"))



                path_name = f"/cluster/tufts/mggg/cdonna01/PRVTP_feb_25_submission/deg_of_prop/figures/{N_SEATS}_seats/{STAT}_combined_support/{g}/{pi_type}/{cohesion}/{election_type}"
                file_name = f"{N_SEATS}_seats_{STAT}_combined_support_{election_type}_{g}_{pi_type}_{cohesion}.png"
                path = Path(path_name)
                # Create the directory
                path.mkdir(parents=True, exist_ok=True)
                plt.tight_layout()
                plt.savefig(f"{path_name}/{file_name}",dpi=300)
                plt.close()


data_frame = pd.DataFrame.from_dict(degrees)
data_frame = data_frame.round(4)
data_frame.to_csv(f"/cluster/tufts/mggg/cdonna01/PRVTP_feb_25_submission/deg_of_prop/data/{N_SEATS}_seats_disprop_2_bloc_{STAT}.csv")
# Out:
#  stv slate-CS-C UU cohesion full
# Average S-C -0.06
# Average |S-C| 0.08
#
#  borda slate-CS-C UU cohesion full
# Average S-C -0.18
# Average |S-C| 0.19
#
#  stv slate-CS-C UU cohesion polarized
# Average S-C -0.05
# Average |S-C| 0.08
#
#  borda slate-CS-C UU cohesion polarized
# Average S-C -0.18
# Average |S-C| 0.19
#
#  stv slate-CS-C UX cohesion full
# Average S-C -0.08
# Average |S-C| 0.11
#
#  borda slate-CS-C UX cohesion full
# Average S-C -0.16
# Average |S-C| 0.17
#
#  stv slate-CS-C UX cohesion polarized
# Average S-C -0.08
# Average |S-C| 0.12
#
#  borda slate-CS-C UX cohesion polarized
# Average S-C -0.15
# Average |S-C| 0.19
#
#  stv slate-CS-C XXsame cohesion full
# Average S-C -0.09
# Average |S-C| 0.11
#
#  borda slate-CS-C XXsame cohesion full
# Average S-C -0.15
# Average |S-C| 0.17
#
#  stv slate-CS-C XXsame cohesion polarized
# Average S-C -0.09
# Average |S-C| 0.11
#
#  borda slate-CS-C XXsame cohesion polarized
# Average S-C -0.16
# Average |S-C| 0.18
#
#  stv slate-CS-C XXdif cohesion full
# Average S-C -0.08
# Average |S-C| 0.11
#
#  borda slate-CS-C XXdif cohesion full
# Average S-C -0.13
# Average |S-C| 0.16
#
#  stv slate-CS-C XXdif cohesion polarized
# Average S-C -0.07
# Average |S-C| 0.11
#
#  borda slate-CS-C XXdif cohesion polarized
# Average S-C -0.14
# Average |S-C| 0.18
#
#  stv slate-CS-W UU cohesion full
# Average S-C 0.05
# Average |S-C| 0.08
#
#  borda slate-CS-W UU cohesion full
# Average S-C 0.17
# Average |S-C| 0.18
#
#  stv slate-CS-W UU cohesion polarized
# Average S-C 0.04
# Average |S-C| 0.09
#
#  borda slate-CS-W UU cohesion polarized
# Average S-C 0.17
# Average |S-C| 0.19
#
#  stv slate-CS-W UX cohesion full
# Average S-C 0.01
# Average |S-C| 0.09
#
#  borda slate-CS-W UX cohesion full
# Average S-C 0.13
# Average |S-C| 0.17
#
#  stv slate-CS-W UX cohesion polarized
# Average S-C 0.01
# Average |S-C| 0.09
#
#  borda slate-CS-W UX cohesion polarized
# Average S-C 0.13
# Average |S-C| 0.17
#
#  stv slate-CS-W XXsame cohesion full
# Average S-C -0.02
# Average |S-C| 0.08
#
#  borda slate-CS-W XXsame cohesion full
# Average S-C 0.10
# Average |S-C| 0.14
#
#  stv slate-CS-W XXsame cohesion polarized
# Average S-C -0.02
# Average |S-C| 0.09
#
#  borda slate-CS-W XXsame cohesion polarized
# Average S-C 0.10
# Average |S-C| 0.15
#
#  stv slate-CS-W XXdif cohesion full
# Average S-C 0.01
# Average |S-C| 0.08
#
#  borda slate-CS-W XXdif cohesion full
# Average S-C 0.12
# Average |S-C| 0.16
#
#  stv slate-CS-W XXdif cohesion polarized
# Average S-C -0.00
# Average |S-C| 0.09
#
#  borda slate-CS-W XXdif cohesion polarized
# Average S-C 0.12
# Average |S-C| 0.17
#
#  stv slate-BT UU cohesion full
# Average S-C -0.00
# Average |S-C| 0.08
#
#  borda slate-BT UU cohesion full
# Average S-C -0.00
# Average |S-C| 0.10
#
#  stv slate-BT UU cohesion polarized
# Average S-C -0.01
# Average |S-C| 0.07
#
#  borda slate-BT UU cohesion polarized
# Average S-C -0.00
# Average |S-C| 0.11
#
#  stv slate-BT UX cohesion full
# Average S-C -0.03
# Average |S-C| 0.07
#
#  borda slate-BT UX cohesion full
# Average S-C -0.01
# Average |S-C| 0.08
#
#  stv slate-BT UX cohesion polarized
# Average S-C -0.03
# Average |S-C| 0.07
#
#  borda slate-BT UX cohesion polarized
# Average S-C -0.01
# Average |S-C| 0.09
#
#  stv slate-BT XXsame cohesion full
# Average S-C -0.03
# Average |S-C| 0.07
#
#  borda slate-BT XXsame cohesion full
# Average S-C -0.01
# Average |S-C| 0.08
#
#  stv slate-BT XXsame cohesion polarized
# Average S-C -0.02
# Average |S-C| 0.06
#
#  borda slate-BT XXsame cohesion polarized
# Average S-C -0.01
# Average |S-C| 0.09
#
#  stv slate-BT XXdif cohesion full
# Average S-C -0.03
# Average |S-C| 0.08
#
#  borda slate-BT XXdif cohesion full
# Average S-C -0.00
# Average |S-C| 0.08
#
#  stv slate-BT XXdif cohesion polarized
# Average S-C -0.04
# Average |S-C| 0.07
#
#  borda slate-BT XXdif cohesion polarized
# Average S-C -0.00
# Average |S-C| 0.08
#
#  stv slate-PL UU cohesion full
# Average S-C -0.01
# Average |S-C| 0.08
#
#  borda slate-PL UU cohesion full
# Average S-C -0.01
# Average |S-C| 0.15
#
#  stv slate-PL UU cohesion polarized
# Average S-C -0.01
# Average |S-C| 0.08
#
#  borda slate-PL UU cohesion polarized
# Average S-C -0.01
# Average |S-C| 0.16
#
#  stv slate-PL UX cohesion full
# Average S-C -0.02
# Average |S-C| 0.08
#
#  borda slate-PL UX cohesion full
# Average S-C -0.02
# Average |S-C| 0.14
#
#  stv slate-PL UX cohesion polarized
# Average S-C -0.02
# Average |S-C| 0.08
#
#  borda slate-PL UX cohesion polarized
# Average S-C -0.02
# Average |S-C| 0.16
#
#  stv slate-PL XXsame cohesion full
# Average S-C -0.03
# Average |S-C| 0.07
#
#  borda slate-PL XXsame cohesion full
# Average S-C -0.00
# Average |S-C| 0.10
#
#  stv slate-PL XXsame cohesion polarized
# Average S-C -0.01
# Average |S-C| 0.07
#
#  borda slate-PL XXsame cohesion polarized
# Average S-C 0.01
# Average |S-C| 0.12
#
#  stv slate-PL XXdif cohesion full
# Average S-C -0.01
# Average |S-C| 0.07
#
#  borda slate-PL XXdif cohesion full
# Average S-C 0.01
# Average |S-C| 0.12
#
#  stv slate-PL XXdif cohesion polarized
# Average S-C -0.01
# Average |S-C| 0.07
#
#  borda slate-PL XXdif cohesion polarized
# Average S-C 0.01
# Average |S-C| 0.14
